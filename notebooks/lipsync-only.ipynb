# %%
# !pip install torchvision librosa==0.9.2 opencv-python-headless ffmpeg-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.3/214.3 kB 4.7 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.0 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 31.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 9.3 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.3 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 69.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 88.9 MB/s eta 0:00:00:00:01
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.8.93
#     Uninstalling nvidia-nvjitlink-cu12-12.8.93:
# ...

# %%
import os
import shutil
import torch
from IPython.display import FileLink

# %%
print("GPU Available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("CUDA Device:", torch.cuda.get_device_name(0))
    # Set device to GPU
    device = torch.device("cuda")
else:
    print("No GPU available - using CPU")
    device = torch.device("cpu")
# Out:
# GPU Available: True
# CUDA Device: Tesla T4

# %%
print("GPU Available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("CUDA Device:", torch.cuda.get_device_name(0))
    # Set device to GPU
    device = torch.device("cuda")
else:
    print("No GPU available - using CPU")
    device = torch.device("cpu")
# Out:
# GPU Available: True
# CUDA Device: Tesla T4

# %%
# ---------------------------------------------------
face_video = "/kaggle/input/modi-voice/modi_video.mp4"  # Video with face
audio_file = "/kaggle/input/modi-voice/tts-audio-2025-04-01T16_07_18.848Z.mp3"  # Audio file

# %%
preprocessed_video = "preprocessed_face5.mp4"
# !ffmpeg -i "{face_video}" -c:v libx264 -profile:v high -crf 20 -pix_fmt yuv420p -strict -2 "{preprocessed_video}"
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
os.makedirs("temp", exist_ok=True)
os.makedirs("results", exist_ok=True)

# %%
import os

print("Preprocessed video exists:", os.path.exists("preprocessed_face5.mp4"))
print("Audio file exists:", os.path.exists(audio_file))
print("Checkpoint exists:", os.path.exists("/kaggle/input/wav2lip/Wav2Lip/checkpoints/wav2lip_gan.pth"))
# Out:
# Preprocessed video exists: True
# Audio file exists: True
# Checkpoint exists: True

# %%
# !python /kaggle/input/wav2lip/Wav2Lip/inference.py \
--checkpoint_path /kaggle/input/wav2lip/Wav2Lip/checkpoints/wav2lip_gan.pth \
--face "{preprocessed_video}" \
--audio "{audio_file}" \
--outfile temp/result6.avi \
--resize_factor 1 \
--fps 25 \
--face_det_batch_size 4 \
--wav2lip_batch_size 16 \
--nosmooth
# Out:
# Using cuda for inference.
# Reading video frames...
# Number of frames available for inference: 226
# Extracting raw audio...
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
# !ffmpeg -i temp/result6.avi -vcodec libx264 -acodec aac results/result6.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...
